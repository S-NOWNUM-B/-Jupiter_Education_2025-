# %% [markdown]
# АНАЛИЗ ДАННЫХ ШКОЛ КАЗАХСТАНА

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Импорт библиотек для анализа данных

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Импорт библиотек для графической визуализации данных

# %%
df = pd.read_excel('Schools Data.xlsx')
df.head()
# Out:
#    Unnamed: 0  ID               region  \
# 0           0   1  Акмолинская область
# 1           1   2  Акмолинская область
# 2           2   3  Акмолинская область
# 3           3   4  Акмолинская область
# 4           4   5  Акмолинская область
#
#                                          school_type  total_students_2018  \
# 0  общеобразовательная школа, опорная школа (ресу...                  833
# 1                          общеобразовательная школа                  528
# 2  общеобразовательная школа, интернат при общеоб...                  714
# 3                          общеобразовательная школа                  354
# 4  общеобразовательная школа, малокомплектная шко...                  139
#
#    total_after_9_2018  total_after_11_2018  diff_teens_2018  \
# 0                  70                 42.0              8.0
# 1                  52                 18.0              0.0
# 2                  56                 37.0              2.0
# 3                  33                 18.0              0.0
# 4                  20                 15.0              0.0
#
#    deficit_places_2018  3_times_school_2018  ...  total_students_9  \
# 0                  0.0                    0  ...          0.081464
# 1                  0.0                    0  ...          0.098901
# 2                  0.0                    0  ...          0.073834
# 3                 21.0                    0  ...          0.085427
# 4                  0.0                    0  ...          0.134615
#
#    total_students_10  total_students_11  nationality_diversity_index  \
# 0           0.018890           0.049587                     0.904265
# 1           0.047619           0.031136                     0.889412
# 2           0.034974           0.051813                     0.350848
# 3           0.022613           0.045226                     0.861186
# 4           0.044872           0.096154                     0.902487
#
#    load_ratio  drinking_water_presence  qedu_top_uni  qedu_passed_ent  \
# 0    1.366129                       да      0.047619         1.000000
# 1    1.011111                       да      0.222222         1.000000
# 2    0.919048                       да      0.108108         0.909091
# 3    1.658333                       да      0.000000         0.888889
# 4    0.331915                       да      0.066667         0.857143
#
#    qedu_continued_education  qedu_elite_achievements
# 0                  1.000000                 0.056856
# 1                  1.000000                 0.014740
# 2                  1.000000                 0.050197
# 3                  0.969697                 0.000000
# 4                  1.000000                 0.000000
#
# [5 rows x 212 columns]

# %% [markdown]
# Загружаем Excel-файл с данными о школах

# %%
print("Размер датасета:", df.shape)

df.columns.tolist()
# Out:
# Размер датасета: (6064, 212)
# ['Unnamed: 0',
#  'ID',
#  'region',
#  'school_type',
#  'total_students_2018',
#  'total_after_9_2018',
#  'total_after_11_2018',
#  'diff_teens_2018',
#  'deficit_places_2018',
#  '3_times_school_2018',
#  'barrier_free_2018',
#  'stud_have_book_count_2018',
#  'ip_higher_4mb_2018',
#  'poor_fams_2018',
#  'poor_fams_food_2018',
#  'dorms_for_villages_2018',
#  'total_teachers_2018',
#  'teachers_1_category_2018',
#  'higher_edu_teachers_2017',
#  'master_teachers',
#  'out_of_system_teachers_2018',
#  'in_emergency_2018',
#  'need_repair_2018',
#  'school_city_dist',
#  'only_out_toilet_2018',
#  'school_density_in_10km',
#  'school_density_in_3km',
#  'school_density_in1.5km',
#  'out_in_toilets_2018',
#  'total_comp_2018',
#  'interactive_boards_2017',
#  'cameras__2017',
#  'messa_2018',
#  'sport_stud',
#  'art_stud',
#  'appl_art_stud',
#  'technical_stud',
#  'soc_student',
#  'bio_eco_stud',
#  'tourist_stud',
#  'nat_math_stud',
#  'lang_stud',
#  'other_stud',
#  'add_edu_stud',
#  'high_category_teachers_2018',
#  'eng_informatics_teachers',
#  'eng_phys_teachers',
#  'eng_chem_teachers',
#  'eng_bio_teachers',
#  'location',
#  'tip_organizacii_obrazovaniya',
#  'open_date',
#  'student_delivery',
#  'magnet_school',
#  'num_libraries',
#  'library_area',
#  'number_library_reading_rooms',
#  'library_reading_room_sitting_places',
#  'library_num_of_readers',
#  'library_num_of_visits',
#  'given_books',
#  'library_books_overall',
#  'ebooks_count_2017',
#  'canteen',
#  'canteen_places',
#  'buffet',
#  'buffet_places',
#  'nutrition_in_apapted_premises',
#  'computer_availability_2017',
#  'computer_overall_2017',
#  'computer_w_internet_2017',
#  'computers_education',
#  'computer_for_teacher_2017',
#  'comp_count_need_repair_2017',
#  'internet_speed_mbit_2017',
#  'interactive_boards_2017.1',
#  'gym_2017',
#  'gym_equipment_2017',
#  'civil_protection_alert_system_2017',
#  'panic_button_2017',
#  'tourniquet_2017',
#  'museum',
#  'camp_2017',
#  'building_type_typical',
#  'heating_type_2017',
#  'building_condition_2017',
#  'building_type_2017',
#  'building_capacity_2017',
#  'hot_water_2017',
#  'import_water',
#  'building_area_2017',
#  'building_working_area_2017',
#  'building_ownership_2017',
#  'landscaping',
#  'toilet_2017',
#  'classrooms_num',
#  'classrooms_area',
#  'lingaphone_cab_2017',
#  'lingaphone_multimedia_cab_2017',
#  'med_cab_2017',
#  'edu_lang_2017',
#  'future_edu_lang_2017',
#  'spec_school_2017',
#  'edu_from_class_num_2017',
#  'spec_edu_from_class_num_2017',
#  'deep_spec_edu_classes_2017',
#  'clubs_2017',
#  'musical_club',
#  'shift_count_2017',
#  'special_classes',
#  'prolonged_day_groups',
#  'combined_class_2017',
#  'class_count_2017',
#  'class_count_1_shift_2017',
#  'class_count_2_shift_2017',
#  'class_count_3_shift_2017',
#  'class_count_4_shift_2017',
#  'total_after_9_2017',
#  'college_after_9_2017',
#  'applied_10_after_9_2017',
#  'total_after_11_2017',
#  'total_teachers_2017',
#  'academic_degree_teachers_2017',
#  'qualified_teachers_2017',
#  'eng_lang_teachers_2017',
#  'out_of_system_teachers_2017',
#  'need_teachers_2017',
#  'staff_num',
#  'zavuch_num',
#  'high_category_teachers_2017',
#  'teachers_1_category_2017',
#  'teachers_2_category_2017',
#  'teachers_no_category_2017',
#  'experience_teachers_under_3_years_2017',
#  'experience_teachers_between_3_5_years_2017',
#  'experience_teachers_between_6_10_years_2017',
#  'experience_teachers_between_11_15_years_2017',
#  'experience_teachers_between_16_20_years_2017',
#  'experience_teachers_20+_years_2017',
#  'higher_edu_teachers_2017.1',
#  'tech_spec_edu_teachers_2017',
#  'middle_edu_teachers_2017',
#  'age_teachers_under_25_2017',
#  'age_teachers_between_25_29_2017',
#  'age_teachers_between_30_34_2017',
#  'age_teachers_between_35_39_2017',
#  'age_teachers_between_40_44_2017',
#  'age_teachers_between_45_49_2017',
#  'age_teachers_between_50_54_2017',
#  'age_teachers_between_55_59_2017',
#  'age_teachers_59+_years_2017',
#  'retired_age_man_teachers_2017',
#  'retired_age_woman_teachers_2017',
#  'total_students_2017',
#  'boys_2017',
#  'girls_2017',
#  'evening_students',
#  'using_clubs_students_2017',
#  'students_without_parents_2017',
#  'disabled_students',
#  'students_without_parent_help_2017',
#  'student_with_financial_aid',
#  'student_books_2017',
#  'hot_food_2017',
#  'free_hot_food_2017',
#  'student_edu_lang_rus_2017',
#  'student_edu_lang_kaz_2017',
#  'student_edu_lang_uyghur_2017',
#  'student_edu_lang_uzbek_2017',
#  'student_edu_lang_tadjik_2017',
#  'russian_students',
#  'kazakh_students',
#  'other_nationality_students',
#  'classrooms_per_student',
#  'classroom_average_area',
#  'working_area_ratio',
#  'diagnostic_cab',
#  'audiologist_cab',
#  'psychiatrist_cab',
#  'dentist_cab',
#  'psychologist_cab',
#  'no_special_cabs',
#  'medical_physical_cab',
#  'neuropatologist_cab',
#  'medical_cab',
#  'pedagog_psychologist_cab',
#  'кабинет психиатра ',
#  'police_inspector_cab',
#  'speech_terapist_cab',
#  'ophtalmologist_cab',
#  'average_students_per_class',
#  'average_students_per_teacher',
#  'average_staff_per_area',
#  'sex_diversity_index',
#  'total_students_1',
#  'total_students_2',
#  'total_students_3',
#  'total_students_4',
#  'total_students_5',
#  'total_students_6',
#  'total_students_7',
#  'total_students_8',
#  'total_students_9',
#  'total_students_10',
#  'total_students_11',
#  'nationality_diversity_index',
#  'load_ratio',
#  'drinking_water_presence',
#  'qedu_top_uni',
#  'qedu_passed_ent',
#  'qedu_continued_education',
#  'qedu_elite_achievements']

# %% [markdown]
# Получаем информацию о размере данных и названиях столбцов

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6064 entries, 0 to 6063
# Columns: 212 entries, Unnamed: 0 to qedu_elite_achievements
# dtypes: bool(14), float64(111), int64(54), object(33)
# memory usage: 9.2+ MB

# %% [markdown]
# Информация о типах данных

# %%
df.describe()
# Out:
#         Unnamed: 0            ID  total_students_2018  total_after_9_2018  \
# count  6064.000000   6064.000000          6064.000000         6064.000000
# mean   3031.500000  12187.230376           424.679090           31.432388
# std    1750.670348  25182.532067           519.137316           35.737803
# min       0.000000      1.000000             0.000000            0.000000
# 25%    1515.750000   1808.750000            70.000000            6.000000
# 50%    3031.500000   3872.500000           214.000000           17.000000
# 75%    4547.250000   5902.250000           607.250000           46.250000
# max    6063.000000  99175.000000          4387.000000          264.000000
#
#        total_after_11_2018  diff_teens_2018  deficit_places_2018  \
# count          6063.000000      6063.000000          6064.000000
# mean             18.597394         0.900874            27.708608
# std              22.869064         3.661066           111.486110
# min               0.000000         0.000000             0.000000
# 25%               0.000000         0.000000             0.000000
# 50%              11.000000         0.000000             0.000000
# 75%              28.000000         1.000000             0.000000
# max             236.000000       164.000000          1987.000000
#
#        3_times_school_2018  barrier_free_2018  stud_have_book_count_2018  ...  \
# count          6064.000000        6064.000000                6061.000000  ...
# mean              0.016161           0.866260                 411.524831  ...
# std               0.126105           0.340401                 508.636903  ...
# min               0.000000           0.000000                   0.000000  ...
# 25%               0.000000           1.000000                  66.000000  ...
# 50%               0.000000           1.000000                 204.000000  ...
# 75%               0.000000           1.000000                 582.000000  ...
# max               1.000000           1.000000                4076.000000  ...
#
#        total_students_8  total_students_9  total_students_10  \
# count       6064.000000       6064.000000        6064.000000
# mean           0.075624          0.071550           0.036617
# std            0.040132          0.039508           0.033720
# min            0.000000          0.000000           0.000000
# 25%            0.060606          0.055871           0.000000
# 50%            0.076206          0.071665           0.035993
# 75%            0.092965          0.088371           0.053663
# max            0.453782          0.520833           0.552083
#
#        total_students_11  nationality_diversity_index   load_ratio  \
# count        6064.000000                  6064.000000  6064.000000
# mean            0.039051                     0.413378     0.910642
# std             0.034942                     0.404306     0.660891
# min             0.000000                    -1.250000     0.000000
# 25%             0.000000                     0.000000     0.410221
# 50%             0.038328                     0.254677     0.791986
# 75%             0.058043                     0.856137     1.243750
# max             0.518519                     1.000000     5.850746
#
#        qedu_top_uni  qedu_passed_ent  qedu_continued_education  \
# count   6064.000000      4232.000000               6064.000000
# mean       0.022928         0.852766                  0.992745
# std        0.101827         0.164851                  0.032561
# min        0.000000         0.000000                  0.000000
# 25%        0.000000         0.769231                  1.000000
# 50%        0.000000         0.888889                  1.000000
# 75%        0.000000         1.000000                  1.000000
# max        4.000000         1.000000                  1.000000
#
#        qedu_elite_achievements
# count              6063.000000
# mean                  0.008695
# std                   0.030392
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.003753
# max                   1.000000
#
# [8 rows x 165 columns]

# %% [markdown]
# Получаем описательную статистику по числовым признакам

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# ID                             0
# region                         0
# school_type                    0
# total_students_2018            0
#                             ...
# drinking_water_presence        0
# qedu_top_uni                   0
# qedu_passed_ent             1832
# qedu_continued_education       0
# qedu_elite_achievements        1
# Length: 212, dtype: int64

# %% [markdown]
# Проверка наличия пропусков

# %%
print("Уникальные регионы:")
print(df['region'].value_counts())
# Out:
# Уникальные регионы:
# region
# Алматинская область               693
# Туркестанская область             669
# Восточно-Казахстанская область    624
# Акмолинская область               486
# Костанайская область              474
# Северо-Казахстанская область      467
# Карагандинская область            443
# Жамбылская область                397
# Западно-Казахстанская область     360
# Актюбинская область               314
# Павлодарская область              294
# Кызылординская область            284
# г.Алматы                          194
# Атырауская область                165
# Мангистауская область             129
# г.Астана                           70
# г.Шымкент                           1
# Name: count, dtype: int64

# %% [markdown]
# Анализ категориальных переменных - регионы

# %%
gdp_mapping = {
    'Акмолинская область': 2500000,
    'Актюбинская область': 3200000,
    'Алматинская область': 3800000,
    'Атырауская область': 8500000,
    'Восточно-Казахстанская область': 3100000,
    'Жамбылская область': 1800000,
    'Западно-Казахстанская область': 3500000,
    'Карагандинская область': 4200000,
    'Костанайская область': 2300000,
    'Кызылординская область': 2100000,
    'Мангистауская область': 5200000,
    'Павлодарская область': 2900000,
    'Северо-Казахстанская область': 1500000,
    'Туркестанская область': 1600000,
    'г.Алматы': 7800000,
    'г.Астана': 6500000,
    'г.Шымкент': 2200000
}

df['gdp'] = df['region'].map(gdp_mapping)
print("Колонка ВВП добавлена")
df[['region', 'gdp']].drop_duplicates().head()
# Out:
# Колонка ВВП добавлена
#                               region      gdp
# 0                Акмолинская область  2500000
# 486              Актюбинская область  3200000
# 800              Алматинская область  3800000
# 1493              Атырауская область  8500000
# 1658  Восточно-Казахстанская область  3100000

# %% [markdown]
# Добавление колонки с ВВП региона

# %%
print("Средний процент сдавших ЕНТ:", df['qedu_passed_ent'].mean())

print("Медианный процент:", df['qedu_passed_ent'].median())

print("Минимум:", df['qedu_passed_ent'].min())
print("Максимум:", df['qedu_passed_ent'].max())
# Out:
# Средний процент сдавших ЕНТ: 0.8527656974515695
# Медианный процент: 0.8888888888888888
# Минимум: 0.0
# Максимум: 1.0

# %% [markdown]
# Анализ результатов ЕНТ

# %%
df.groupby('region')['qedu_passed_ent'].mean().sort_values(ascending=False)
# Out:
# region
# г.Шымкент                         0.988235
# г.Алматы                          0.960477
# Кызылординская область            0.939485
# Жамбылская область                0.886841
# Костанайская область              0.881999
# Павлодарская область              0.878443
# Западно-Казахстанская область     0.876527
# Северо-Казахстанская область      0.864459
# Алматинская область               0.859183
# Карагандинская область            0.852747
# Мангистауская область             0.830924
# Актюбинская область               0.830858
# Акмолинская область               0.829665
# Восточно-Казахстанская область    0.810315
# г.Астана                          0.808646
# Туркестанская область             0.805181
# Атырауская область                0.742401
# Name: qedu_passed_ent, dtype: float64

# %% [markdown]
# Средние результаты ЕНТ по регионам

# %%
region_avg = df.groupby('region')[['gdp', 'qedu_passed_ent']].mean()
correlation = region_avg['gdp'].corr(region_avg['qedu_passed_ent'])
print(f"Корреляция ВВП и результатов ЕНТ: {correlation:.4f}")
# Out:
# Корреляция ВВП и результатов ЕНТ: -0.2781

# %% [markdown]
# Расчет корреляции между ВВП региона и результатами ЕНТ

# %%
plt.figure(figsize=(12, 6))
region_avg = df.groupby('region')['qedu_passed_ent'].mean().sort_values()

plt.barh(region_avg.index, region_avg.values, color='steelblue')
plt.xlabel('Средний процент сдавших ЕНТ')
plt.title('Результаты ЕНТ по регионам')
plt.grid(axis='x', alpha=0.3)

plt.show()

# %% [markdown]
# Гистограмма результатов ЕНТ по регионам

# %%
plt.figure(figsize=(10, 6))
df_plot = df.groupby('region')[['gdp', 'qedu_passed_ent']].mean()

plt.scatter(df_plot['gdp'], df_plot['qedu_passed_ent'], s=100, alpha=0.6, color='coral')
plt.xlabel('ВВП региона')
plt.ylabel('Средний % сдавших ЕНТ')
plt.title('Взаимосвязь ВВП региона и результатов ЕНТ')
plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# Scatter plot взаимосвязи ВВП и результатов ЕНТ

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['qedu_passed_ent'], bins=30, kde=True, color='skyblue')

plt.xlabel('Процент сдавших ЕНТ')
plt.ylabel('Количество школ')
plt.title('Распределение результатов ЕНТ')
plt.axvline(df['qedu_passed_ent'].mean(), color='red', linestyle='--', 
            label=f"Среднее: {df['qedu_passed_ent'].mean():.2%}")
plt.legend()

plt.show()

# %% [markdown]
# Распределение результатов ЕНТ по всем школам

# %%
plt.figure(figsize=(10, 6))
df.groupby('region')['gdp'].first().sort_values().plot(kind='barh', color='lightgreen')

plt.xlabel('ВВП')
plt.title('ВВП по регионам')
plt.grid(axis='x', alpha=0.3)

plt.show()

# %% [markdown]
# Сравнение ВВП регионов

# %%
if 'total_teachers_2017' in df.columns:
    corr = df['total_teachers_2017'].corr(df['qedu_passed_ent'])
    print(f"Корреляция учителей и ЕНТ: {corr:.4f}")
else:
    print("Колонка total_teachers_2017 не найдена")
# Out:
# Корреляция учителей и ЕНТ: 0.0233

# %% [markdown]
# Проверка гипотезы о влиянии количества учителей на результаты

# %%
import os

os.makedirs('reports/by_regions', exist_ok=True)

for region in df['region'].unique():
    region_df = df[df['region'] == region]
    filename = f"reports/by_regions/{region.replace(' ', '_')}.xlsx"
    region_df.to_excel(filename, index=False)
    print(f"✓ {region}: {len(region_df)} школ")

print("\nФайлы сохранены в reports/by_regions/")
# Out:
# ✓ Акмолинская область: 486 школ
# ✓ Актюбинская область: 314 школ
# ✓ Алматинская область: 693 школ
# ✓ Атырауская область: 165 школ
# ✓ Восточно-Казахстанская область: 624 школ
# ✓ г.Алматы: 194 школ
# ✓ г.Астана: 70 школ
# ✓ г.Шымкент: 1 школ
# ✓ Жамбылская область: 397 школ
# ✓ Западно-Казахстанская область: 360 школ
# ✓ Карагандинская область: 443 школ
# ✓ Костанайская область: 474 школ
# ✓ Кызылординская область: 284 школ
# ✓ Мангистауская область: 129 школ
# ✓ Павлодарская область: 294 школ
# ✓ Северо-Казахстанская область: 467 школ
# ✓ Туркестанская область: 669 школ
#
# Файлы сохранены в reports/by_regions/

# %% [markdown]
# Создание отдельных файлов по регионам

# %%
os.makedirs('reports/blacklist_ent', exist_ok=True)

blacklist = df[df['qedu_passed_ent'] < 0.5]
blacklist.to_excel('reports/blacklist_ent/TOTAL_blacklist.xlsx', index=False)

print(f"Всего школ в чёрном списке: {len(blacklist)}")
print(f"Это {len(blacklist)/len(df)*100:.2f}% от общего числа\n")

for region in df['region'].unique():
    region_bl = blacklist[blacklist['region'] == region]
    if len(region_bl) > 0:
        filename = f"reports/blacklist_ent/blacklist_{region.replace(' ', '_')}.xlsx"
        region_bl.to_excel(filename, index=False)
        print(f"✓ {region}: {len(region_bl)} школ")

print("\nЧёрные списки сохранены")
# Out:
# Всего школ в чёрном списке: 110
# Это 1.81% от общего числа
#
# ✓ Акмолинская область: 7 школ
# ✓ Актюбинская область: 10 школ
# ✓ Алматинская область: 7 школ
# ✓ Атырауская область: 12 школ
# ✓ Восточно-Казахстанская область: 22 школ
# ✓ г.Астана: 3 школ
# ✓ Жамбылская область: 3 школ
# ✓ Западно-Казахстанская область: 3 школ
# ✓ Карагандинская область: 5 школ
# ✓ Костанайская область: 8 школ
# ✓ Мангистауская область: 2 школ
# ✓ Павлодарская область: 3 школ
# ✓ Северо-Казахстанская область: 7 школ
# ✓ Туркестанская область: 18 школ
#
# Чёрные списки сохранены

# %% [markdown]
# Чёрный список школ с низкими результатами ЕНТ

# %%
os.makedirs('reports/material_problems', exist_ok=True)

problems = df[
    (df['drinking_water_presence'].isin(['нет', 'no'])) |
    (df['load_ratio'] > 1.5) |
    (df['deficit_places_2018'] > 0)
]

problems.to_excel('reports/material_problems/TOTAL_problems.xlsx', index=False)
print(f"Школ с проблемами: {len(problems)}\n")

for region in df['region'].unique():
    region_prob = problems[problems['region'] == region]
    if len(region_prob) > 0:
        filename = f"reports/material_problems/problems_{region.replace(' ', '_')}.xlsx"
        region_prob.to_excel(filename, index=False)
        print(f"✓ {region}: {len(region_prob)} школ")
# Out:
# Школ с проблемами: 1773
#
# ✓ Акмолинская область: 93 школ
# ✓ Актюбинская область: 90 школ
# ✓ Алматинская область: 246 школ
# ✓ Атырауская область: 82 школ
# ✓ Восточно-Казахстанская область: 129 школ
# ✓ г.Алматы: 81 школ
# ✓ г.Астана: 48 школ
# ✓ Жамбылская область: 172 школ
# ✓ Западно-Казахстанская область: 100 школ
# ✓ Карагандинская область: 67 школ
# ✓ Костанайская область: 160 школ
# ✓ Кызылординская область: 83 школ
# ✓ Мангистауская область: 65 школ
# ✓ Павлодарская область: 32 школ
# ✓ Северо-Казахстанская область: 49 школ
# ✓ Туркестанская область: 276 школ

# %% [markdown]
# Список школ с проблемами материальной обеспеченности

# %%
os.makedirs('reports/top_teachers', exist_ok=True)

if 'eng_informatics_teachers' in df.columns:
    df['total_eng'] = (df['eng_informatics_teachers'].fillna(0) + 
                       df['eng_phys_teachers'].fillna(0) +
                       df['eng_chem_teachers'].fillna(0) + 
                       df['eng_bio_teachers'].fillna(0))
    
    top50 = df.nlargest(50, 'total_eng')[['region', 'total_eng']]
    top50.to_excel('reports/top_teachers/TOP_50_english.xlsx', index=False)
    
    print("Топ-10 школ по учителям с английским:")
    print(top50.head(10).to_string(index=False))
    
    for spec, col in [('informatics', 'eng_informatics_teachers'),
                      ('physics', 'eng_phys_teachers'),
                      ('chemistry', 'eng_chem_teachers'),
                      ('biology', 'eng_bio_teachers')]:
        top20 = df.nlargest(20, col)[['region', col]]
        top20.to_excel(f'reports/top_teachers/TOP_20_{spec}.xlsx', index=False)
        print(f"✓ {spec}: топ-20 сохранён")
# Out:
# Топ-10 школ по учителям с английским:
#                 region  total_eng
#     Жамбылская область         13
# Кызылординская область         13
#               г.Астана         12
#     Жамбылская область         12
#     Жамбылская область         12
# Кызылординская область         12
#     Жамбылская область         11
#  Туркестанская область         11
#               г.Алматы         10
#               г.Алматы         10
# ✓ informatics: топ-20 сохранён
# ✓ physics: топ-20 сохранён
# ✓ chemistry: топ-20 сохранён
# ✓ biology: топ-20 сохранён

# %% [markdown]
# Топ школ по учителям со знанием английского языка

# %%
city_cols = [col for col in df.columns if 'city' in col.lower() or 'location' in col.lower()]

if city_cols:
    city_col = city_cols[0]
    
    city_stats = df.groupby(city_col).agg({
        'region': 'first',
        'ID': 'count',
        'total_students_2018': 'sum',
        'qedu_passed_ent': 'mean',
        'load_ratio': 'mean',
        'gdp': 'first'
    }).reset_index()
    
    city_stats.columns = ['Населённый_пункт', 'Регион', 'Количество_школ', 
                          'Всего_учеников', 'Средний_ЕНТ', 'Загруженность', 'ВВП']
    
    city_stats = city_stats.sort_values('Количество_школ', ascending=False)
    city_stats.to_excel('reports/statistics_by_city.xlsx', index=False)
    
    print(f"Статистика по {len(city_stats)} населённым пунктам")
    print("\nТоп-10:")
    print(city_stats.head(10).to_string(index=False))
# Out:
# Статистика по 5922 населённым пунктам
#
# Топ-10:
#  Населённый_пункт                         Регион  Количество_школ  Всего_учеников  Средний_ЕНТ  Загруженность     ВВП
#        159.122787           Павлодарская область               11             513     0.964286       0.306985 2900000
#        222.829077 Восточно-Казахстанская область               10             544     0.847222       0.558156 3100000
#          4.718898 Восточно-Казахстанская область                9            1027     0.585516       0.460436 3100000
#        386.524902            Алматинская область                9            1689     0.965643       0.580273 3800000
#        427.401440 Восточно-Казахстанская область                8            3670     0.841409       1.307247 3100000
#         45.988237           Павлодарская область                7             974     0.952381       0.447747 2900000
#        215.446447            Актюбинская область                6            1888     0.759722       1.229218 3200000
#        182.324306           Павлодарская область                5             361     1.000000       0.182519 2900000
#        295.670876            Актюбинская область                5            2421     0.530303       1.405333 3200000
#        164.443963           Павлодарская область                4             149          NaN       0.743750 2900000

# %% [markdown]
# Статистика по населённым пунктам

# %%
print(f"\nШкол проанализировано: {len(df)}")
print(f"Регионов: {df['region'].nunique()}")
print(f"\nСредний результат ЕНТ: {df['qedu_passed_ent'].mean():.2%}")
print(f"Школ с ЕНТ < 50%: {len(df[df['qedu_passed_ent'] < 0.5])}")
# Out:
# Школ проанализировано: 6064
# Регионов: 17
#
# Средний результат ЕНТ: 85.28%
# Школ с ЕНТ < 50%: 110

# %% [markdown]
# Итоговая сводка выполненной работы

# %% [markdown]
# # Анализ данных школ Казахстана
#
# ## Контрольная работа 9
# ### Выполнил: Stanislav Mamaev
#
# ---
#
# ## Структура проекта:
# 1. Загрузка и первичный анализ данных
# 2. Добавление данных о ВВП регионов
# 3. Визуализация и анализ взаимосвязей
# 4. Проверка гипотез
# 5. Создание отчётов

# %% [markdown]
# ## 1. Импорт необходимых библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline

# Настройки для красивого отображения
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

# %% [markdown]
# Импортируем библиотеки для анализа данных, визуализации и обработки

# %% [markdown]
# ## 2. Загрузка данных Schools Data.xlsx

# %%
# Загрузка данных о школах
df = pd.read_excel('Schools Data.xlsx')

print(f"Размер датасета: {df.shape}")
print(f"Количество строк: {df.shape[0]}")
print(f"Количество столбцов: {df.shape[1]}")

df.head()
# Out:
# Размер датасета: (6064, 212)
# Количество строк: 6064
# Количество столбцов: 212
#    Unnamed: 0  ID               region  \
# 0           0   1  Акмолинская область
# 1           1   2  Акмолинская область
# 2           2   3  Акмолинская область
# 3           3   4  Акмолинская область
# 4           4   5  Акмолинская область
#
#                                          school_type  total_students_2018  \
# 0  общеобразовательная школа, опорная школа (ресу...                  833
# 1                          общеобразовательная школа                  528
# 2  общеобразовательная школа, интернат при общеоб...                  714
# 3                          общеобразовательная школа                  354
# 4  общеобразовательная школа, малокомплектная шко...                  139
#
#    total_after_9_2018  total_after_11_2018  diff_teens_2018  \
# 0                  70                 42.0              8.0
# 1                  52                 18.0              0.0
# 2                  56                 37.0              2.0
# 3                  33                 18.0              0.0
# 4                  20                 15.0              0.0
#
#    deficit_places_2018  3_times_school_2018  ...  total_students_9  \
# 0                  0.0                    0  ...          0.081464
# 1                  0.0                    0  ...          0.098901
# 2                  0.0                    0  ...          0.073834
# 3                 21.0                    0  ...          0.085427
# 4                  0.0                    0  ...          0.134615
#
#    total_students_10  total_students_11  nationality_diversity_index  \
# 0           0.018890           0.049587                     0.904265
# 1           0.047619           0.031136                     0.889412
# 2           0.034974           0.051813                     0.350848
# 3           0.022613           0.045226                     0.861186
# 4           0.044872           0.096154                     0.902487
#
#    load_ratio  drinking_water_presence  qedu_top_uni  qedu_passed_ent  \
# 0    1.366129                       да      0.047619         1.000000
# 1    1.011111                       да      0.222222         1.000000
# 2    0.919048                       да      0.108108         0.909091
# 3    1.658333                       да      0.000000         0.888889
# 4    0.331915                       да      0.066667         0.857143
#
#    qedu_continued_education  qedu_elite_achievements
# 0                  1.000000                 0.056856
# 1                  1.000000                 0.014740
# 2                  1.000000                 0.050197
# 3                  0.969697                 0.000000
# 4                  1.000000                 0.000000
#
# [5 rows x 212 columns]

# %% [markdown]
# Загружаем Excel-файл с данными о школах Казахстана и выводим первые строки

# %% [markdown]
# ## 3. Первичный разведывательный анализ данных

# %%
# Список всех колонок
print("Список колонок в датасете:")
print("=" * 60)
for i, col in enumerate(df.columns.tolist(), 1):
    print(f"{i}. {col}")
    
print(f"\nВсего колонок: {len(df.columns)}")
# Out:
# Список колонок в датасете:
# ============================================================
# 1. Unnamed: 0
# 2. ID
# 3. region
# 4. school_type
# 5. total_students_2018
# 6. total_after_9_2018
# 7. total_after_11_2018
# 8. diff_teens_2018
# 9. deficit_places_2018
# 10. 3_times_school_2018
# 11. barrier_free_2018
# 12. stud_have_book_count_2018
# 13. ip_higher_4mb_2018
# 14. poor_fams_2018
# 15. poor_fams_food_2018
# 16. dorms_for_villages_2018
# 17. total_teachers_2018
# 18. teachers_1_category_2018
# 19. higher_edu_teachers_2017
# 20. master_teachers
# 21. out_of_system_teachers_2018
# 22. in_emergency_2018
# 23. need_repair_2018
# 24. school_city_dist
# 25. only_out_toilet_2018
# 26. school_density_in_10km
# 27. school_density_in_3km
# 28. school_density_in1.5km
# 29. out_in_toilets_2018
# 30. total_comp_2018
# 31. interactive_boards_2017
# 32. cameras__2017
# 33. messa_2018
# 34. sport_stud
# 35. art_stud
# 36. appl_art_stud
# 37. technical_stud
# 38. soc_student
# 39. bio_eco_stud
# 40. tourist_stud
# 41. nat_math_stud
# 42. lang_stud
# 43. other_stud
# 44. add_edu_stud
# 45. high_category_teachers_2018
# 46. eng_informatics_teachers
# 47. eng_phys_teachers
# 48. eng_chem_teachers
# 49. eng_bio_teachers
# 50. location
# 51. tip_organizacii_obrazovaniya
# 52. open_date
# 53. student_delivery
# 54. magnet_school
# 55. num_libraries
# 56. library_area
# 57. number_library_reading_rooms
# 58. library_reading_room_sitting_places
# 59. library_num_of_readers
# 60. library_num_of_visits
# 61. given_books
# 62. library_books_overall
# 63. ebooks_count_2017
# 64. canteen
# 65. canteen_places
# 66. buffet
# 67. buffet_places
# 68. nutrition_in_apapted_premises
# 69. computer_availability_2017
# 70. computer_overall_2017
# 71. computer_w_internet_2017
# 72. computers_education
# 73. computer_for_teacher_2017
# 74. comp_count_need_repair_2017
# 75. internet_speed_mbit_2017
# 76. interactive_boards_2017.1
# 77. gym_2017
# 78. gym_equipment_2017
# 79. civil_protection_alert_system_2017
# 80. panic_button_2017
# 81. tourniquet_2017
# 82. museum
# 83. camp_2017
# 84. building_type_typical
# 85. heating_type_2017
# 86. building_condition_2017
# 87. building_type_2017
# 88. building_capacity_2017
# 89. hot_water_2017
# 90. import_water
# 91. building_area_2017
# 92. building_working_area_2017
# 93. building_ownership_2017
# 94. landscaping
# 95. toilet_2017
# 96. classrooms_num
# 97. classrooms_area
# 98. lingaphone_cab_2017
# 99. lingaphone_multimedia_cab_2017
# 100. med_cab_2017
# 101. edu_lang_2017
# 102. future_edu_lang_2017
# 103. spec_school_2017
# 104. edu_from_class_num_2017
# 105. spec_edu_from_class_num_2017
# 106. deep_spec_edu_classes_2017
# 107. clubs_2017
# 108. musical_club
# 109. shift_count_2017
# 110. special_classes
# 111. prolonged_day_groups
# 112. combined_class_2017
# 113. class_count_2017
# 114. class_count_1_shift_2017
# 115. class_count_2_shift_2017
# 116. class_count_3_shift_2017
# 117. class_count_4_shift_2017
# 118. total_after_9_2017
# 119. college_after_9_2017
# 120. applied_10_after_9_2017
# 121. total_after_11_2017
# 122. total_teachers_2017
# 123. academic_degree_teachers_2017
# 124. qualified_teachers_2017
# 125. eng_lang_teachers_2017
# 126. out_of_system_teachers_2017
# 127. need_teachers_2017
# 128. staff_num
# 129. zavuch_num
# 130. high_category_teachers_2017
# 131. teachers_1_category_2017
# 132. teachers_2_category_2017
# 133. teachers_no_category_2017
# 134. experience_teachers_under_3_years_2017
# 135. experience_teachers_between_3_5_years_2017
# 136. experience_teachers_between_6_10_years_2017
# 137. experience_teachers_between_11_15_years_2017
# 138. experience_teachers_between_16_20_years_2017
# 139. experience_teachers_20+_years_2017
# 140. higher_edu_teachers_2017.1
# 141. tech_spec_edu_teachers_2017
# 142. middle_edu_teachers_2017
# 143. age_teachers_under_25_2017
# 144. age_teachers_between_25_29_2017
# 145. age_teachers_between_30_34_2017
# 146. age_teachers_between_35_39_2017
# 147. age_teachers_between_40_44_2017
# 148. age_teachers_between_45_49_2017
# 149. age_teachers_between_50_54_2017
# 150. age_teachers_between_55_59_2017
# 151. age_teachers_59+_years_2017
# 152. retired_age_man_teachers_2017
# 153. retired_age_woman_teachers_2017
# 154. total_students_2017
# 155. boys_2017
# 156. girls_2017
# 157. evening_students
# 158. using_clubs_students_2017
# 159. students_without_parents_2017
# 160. disabled_students
# 161. students_without_parent_help_2017
# 162. student_with_financial_aid
# 163. student_books_2017
# 164. hot_food_2017
# 165. free_hot_food_2017
# 166. student_edu_lang_rus_2017
# 167. student_edu_lang_kaz_2017
# 168. student_edu_lang_uyghur_2017
# 169. student_edu_lang_uzbek_2017
# 170. student_edu_lang_tadjik_2017
# 171. russian_students
# 172. kazakh_students
# 173. other_nationality_students
# 174. classrooms_per_student
# 175. classroom_average_area
# 176. working_area_ratio
# 177. diagnostic_cab
# 178. audiologist_cab
# 179. psychiatrist_cab
# 180. dentist_cab
# 181. psychologist_cab
# 182. no_special_cabs
# 183. medical_physical_cab
# 184. neuropatologist_cab
# 185. medical_cab
# 186. pedagog_psychologist_cab
# 187. кабинет психиатра
# 188. police_inspector_cab
# 189. speech_terapist_cab
# 190. ophtalmologist_cab
# 191. average_students_per_class
# 192. average_students_per_teacher
# 193. average_staff_per_area
# 194. sex_diversity_index
# 195. total_students_1
# 196. total_students_2
# 197. total_students_3
# 198. total_students_4
# 199. total_students_5
# 200. total_students_6
# 201. total_students_7
# 202. total_students_8
# 203. total_students_9
# 204. total_students_10
# 205. total_students_11
# 206. nationality_diversity_index
# 207. load_ratio
# 208. drinking_water_presence
# 209. qedu_top_uni
# 210. qedu_passed_ent
# 211. qedu_continued_education
# 212. qedu_elite_achievements
#
# Всего колонок: 212

# %% [markdown]
# Получаем список всех колонок в датасете

# %%
df.info()

missing = df.isnull().sum()
missing_percent = (missing / len(df)) * 100
missing_df = pd.DataFrame({
    'Колонка': missing.index,
    'Пропущено': missing.values,
    'Процент': missing_percent.values
})
print(missing_df[missing_df['Пропущено'] > 0].to_string(index=False))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6064 entries, 0 to 6063
# Columns: 212 entries, Unnamed: 0 to qedu_elite_achievements
# dtypes: bool(14), float64(111), int64(54), object(33)
# memory usage: 9.2+ MB
#                     Колонка  Пропущено   Процент
#         total_after_11_2018          1  0.016491
#             diff_teens_2018          1  0.016491
#   stud_have_book_count_2018          3  0.049472
#              poor_fams_2018          1  0.016491
#         poor_fams_food_2018          1  0.016491
#         total_teachers_2018          4  0.065963
#    higher_edu_teachers_2017          1  0.016491
#             master_teachers          4  0.065963
# out_of_system_teachers_2018          3  0.049472
#             qedu_passed_ent       1832 30.211082
#     qedu_elite_achievements          1  0.016491

# %% [markdown]
# Проверяем типы данных и наличие пропущенных значений

# %%
# Анализ категориальных колонок
categorical_columns = df.select_dtypes(include=['object']).columns

print("Категориальные колонки и их уникальные значения:")
print("=" * 60)

for col in categorical_columns:
    unique_count = df[col].nunique()
    print(f"\n{col}:")
    print(f"  Уникальных значений: {unique_count}")
    
    if unique_count <= 20:  # Выводим значения только если их не слишком много
        print(f"  Значения: {df[col].unique().tolist()}")
        print(f"  Распределение:")
        print(df[col].value_counts().head(10).to_string())
# Out:
# Категориальные колонки и их уникальные значения:
# ============================================================
#
# region:
#   Уникальных значений: 17
#   Значения: ['Акмолинская область', 'Актюбинская область', 'Алматинская область', 'Атырауская область', 'Восточно-Казахстанская область', 'г.Алматы', 'г.Астана', 'г.Шымкент', 'Жамбылская область', 'Западно-Казахстанская область', 'Карагандинская область', 'Костанайская область', 'Кызылординская область', 'Мангистауская область', 'Павлодарская область', 'Северо-Казахстанская область', 'Туркестанская область']
#   Распределение:
# region
# Алматинская область               693
# Туркестанская область             669
# Восточно-Казахстанская область    624
# Акмолинская область               486
# Костанайская область              474
# Северо-Казахстанская область      467
# Карагандинская область            443
# Жамбылская область                397
# Западно-Казахстанская область     360
# Актюбинская область               314
#
# school_type:
#   Уникальных значений: 72
#
# cameras__2017:
#   Уникальных значений: 1
#   Значения: ['комбинированное']
#   Распределение:
# cameras__2017
# комбинированное    6064
#
# location:
#   Уникальных значений: 3148
#
# tip_organizacii_obrazovaniya:
#   Уникальных значений: 3
#   Значения: ['Организации среднего образования(начального, основного среднего и общего среднего)', 'Специализированные организации образования', 'Организации образования для детей-сирот и детей, оставшихся без попечения родителей']
#   Распределение:
# tip_organizacii_obrazovaniya
# Организации среднего образования(начального, основного среднего и общего среднего)     5978
# Специализированные организации образования                                               85
# Организации образования для детей-сирот и детей, оставшихся без попечения родителей       1
#
# open_date:
#   Уникальных значений: 1885
#
# canteen:
#   Уникальных значений: 2
#   Значения: ['да', 'нет']
#   Распределение:
# canteen
# да     5092
# нет     972
#
# buffet:
#   Уникальных значений: 2
#   Значения: ['нет', 'да']
#   Распределение:
# buffet
# нет    4602
# да     1462
#
# nutrition_in_apapted_premises:
#   Уникальных значений: 3
#   Значения: ['нет', 'да', 0]
#   Распределение:
# nutrition_in_apapted_premises
# нет    3766
# да     2297
# 0         1
#
# computer_availability_2017:
#   Уникальных значений: 2
#   Значения: ['да', 'нет']
#   Распределение:
# computer_availability_2017
# да     6052
# нет      12
#
# gym_2017:
#   Уникальных значений: 2
#   Значения: ['да', 'нет']
#   Распределение:
# gym_2017
# да     5144
# нет     920
#
# gym_equipment_2017:
#   Уникальных значений: 7
#   Значения: ['спортивные площадки,спортивные секции', 'другой', 'спортивный зал, оснащенный стандартным оборудованием,спортивные площадки,спортивные секции', 'спортивные площадки', 'не имеется', 'спортивный зал, оснащенный стандартным оборудованием,спортивные площадки', 'спортивный зал, оснащенный стандартным оборудованием,спортивные площадки,гимнастические городки,спортивные секции']
#   Распределение:
# gym_equipment_2017
# спортивный зал, оснащенный стандартным оборудованием,спортивные площадки,спортивные секции                           1526
# спортивные площадки,спортивные секции                                                                                1163
# спортивные площадки                                                                                                   916
# другой                                                                                                                774
# спортивный зал, оснащенный стандартным оборудованием,спортивные площадки,гимнастические городки,спортивные секции     773
# спортивный зал, оснащенный стандартным оборудованием,спортивные площадки                                              494
# не имеется                                                                                                            418
#
# civil_protection_alert_system_2017:
#   Уникальных значений: 2
#   Значения: ['нет', 'да']
#   Распределение:
# civil_protection_alert_system_2017
# нет    3195
# да     2869
#
# panic_button_2017:
#   Уникальных значений: 2
#   Значения: ['да', 'нет']
#   Распределение:
# panic_button_2017
# да     3354
# нет    2710
#
# tourniquet_2017:
#   Уникальных значений: 2
#   Значения: ['нет', 'да']
#   Распределение:
# tourniquet_2017
# нет    5551
# да      513
#
# museum:
#   Уникальных значений: 3
#   Значения: ['да', 'нет', '0']
#   Распределение:
# museum
# нет    4584
# да     1479
# 0         1
#
# camp_2017:
#   Уникальных значений: 2
#   Значения: ['нет', 'да']
#   Распределение:
# camp_2017
# нет    3379
# да     2685
#
# building_type_typical:
#   Уникальных значений: 6
#   Значения: ['типовое', 'приспособленное', 'типовое,приспособленное', '0', 'типовое,нет', 'нет']
#   Распределение:
# building_type_typical
# типовое                    4645
# приспособленное            1241
# типовое,приспособленное     125
# 0                            48
# типовое,нет                   3
# нет                           2
#
# heating_type_2017:
#   Уникальных значений: 7
#   Значения: ['на твердом топливе', 'центральное', 'электрокотельное', 'с другим видом отопления', 'на жидком топливе', 'на газовом топливе', '0']
#   Распределение:
# heating_type_2017
# на твердом топливе          2667
# центральное                 1305
# на газовом топливе           951
# на жидком топливе            688
# электрокотельное             252
# с другим видом отопления     153
# 0                             48
#
# building_condition_2017:
#   Уникальных значений: 3
#   Значения: ['проведён', 'требует', 'аварийные']
#   Распределение:
# building_condition_2017
# требует      3164
# проведён     2863
# аварийные      37
#
# building_type_2017:
#   Уникальных значений: 8
#   Значения: ['кирпичное', 'другое', 'блочное', 'монолитное', 'деревянное', 'другой', 'саманное', 'каркасное']
#   Распределение:
# building_type_2017
# кирпичное     3951
# блочное       1201
# другое         298
# саманное       256
# другой         167
# деревянное      75
# каркасное       59
# монолитное      57
#
# hot_water_2017:
#   Уникальных значений: 4
#   Значения: ['нет', 'да', 'нет,да', '0']
#   Распределение:
# hot_water_2017
# нет       4280
# да        1678
# нет,да      57
# 0           49
#
# import_water:
#   Уникальных значений: 4
#   Значения: ['нет', 'да', 'нет,да', '0']
#   Распределение:
# import_water
# нет       4367
# да        1627
# 0           49
# нет,да      21
#
# building_ownership_2017:
#   Уникальных значений: 4
#   Значения: ['Собственное', 'Не указано', 'Арендуемое', 'Частично собственное']
#   Распределение:
# building_ownership_2017
# Собственное             5862
# Не указано                98
# Арендуемое                70
# Частично собственное      34
#
# landscaping:
#   Уникальных значений: 3
#   Значения: ['наличие всех видов благоустройств', 'частично благоустроены', 'не благоустроены']
#   Распределение:
# landscaping
# частично благоустроены               3368
# наличие всех видов благоустройств    1994
# не благоустроены                      702
#
# toilet_2017:
#   Уникальных значений: 4
#   Значения: ['наличие теплых и надворных туалетов', 'наличие только теплых туалетов', 'наличие только надворных туалетов', 'нет']
#   Распределение:
# toilet_2017
# наличие теплых и надворных туалетов    2488
# наличие только надворных туалетов      2207
# наличие только теплых туалетов         1274
# нет                                      95
#
# med_cab_2017:
#   Уникальных значений: 3
#   Значения: ['да', 'нет', '0']
#   Распределение:
# med_cab_2017
# да     4565
# нет    1498
# 0         1
#
# edu_lang_2017:
#   Уникальных значений: 4
#   Значения: ['русский', 'казахский', 'казахский,русский', 'другой']
#   Распределение:
# edu_lang_2017
# казахский            3180
# казахский,русский    1614
# русский              1120
# другой                150
#
# future_edu_lang_2017:
#   Уникальных значений: 4
#   Значения: ['русский', 'казахский', 'английский', 'другой']
#   Распределение:
# future_edu_lang_2017
# казахский     4468
# русский       1484
# английский      59
# другой          53
#
# spec_school_2017:
#   Уникальных значений: 4
#   Значения: ['0', 'естественно-математическое', 'другие', 'естественно-математическое,общественно-гуманитарное']
#   Распределение:
# spec_school_2017
# 0                                                      5966
# естественно-математическое                               67
# естественно-математическое,общественно-гуманитарное      19
# другие                                                   12
#
# edu_from_class_num_2017:
#   Уникальных значений: 4
#   Значения: ['1-4', 'предшкольное', '5-8', '9-12']
#   Распределение:
# edu_from_class_num_2017
# предшкольное    4517
# 1-4             1419
# 5-8              111
# 9-12              17
#
# spec_edu_from_class_num_2017:
#   Уникальных значений: 4
#   Значения: ['0', '9-12', '5-8', '1-4']
#   Распределение:
# spec_edu_from_class_num_2017
# 0       5972
# 5-8       46
# 9-12      40
# 1-4        6
#
# drinking_water_presence:
#   Уникальных значений: 4
#   Значения: ['да', 'нет', 'нет,да', '0']
#   Распределение:
# drinking_water_presence
# да        5121
# нет        825
# нет,да      67
# 0           51

# %% [markdown]
# Анализируем категориальные колонки и их значения

# %%
# Описательная статистика
print("Описательная статистика по числовым колонкам:")
print("=" * 60)
df.describe()
# Out:
# Описательная статистика по числовым колонкам:
# ============================================================
#         Unnamed: 0            ID  total_students_2018  total_after_9_2018  \
# count  6064.000000   6064.000000          6064.000000         6064.000000
# mean   3031.500000  12187.230376           424.679090           31.432388
# std    1750.670348  25182.532067           519.137316           35.737803
# min       0.000000      1.000000             0.000000            0.000000
# 25%    1515.750000   1808.750000            70.000000            6.000000
# 50%    3031.500000   3872.500000           214.000000           17.000000
# 75%    4547.250000   5902.250000           607.250000           46.250000
# max    6063.000000  99175.000000          4387.000000          264.000000
#
#        total_after_11_2018  diff_teens_2018  deficit_places_2018  \
# count          6063.000000      6063.000000          6064.000000
# mean             18.597394         0.900874            27.708608
# std              22.869064         3.661066           111.486110
# min               0.000000         0.000000             0.000000
# 25%               0.000000         0.000000             0.000000
# 50%              11.000000         0.000000             0.000000
# 75%              28.000000         1.000000             0.000000
# max             236.000000       164.000000          1987.000000
#
#        3_times_school_2018  barrier_free_2018  stud_have_book_count_2018  ...  \
# count          6064.000000        6064.000000                6061.000000  ...
# mean              0.016161           0.866260                 411.524831  ...
# std               0.126105           0.340401                 508.636903  ...
# min               0.000000           0.000000                   0.000000  ...
# 25%               0.000000           1.000000                  66.000000  ...
# 50%               0.000000           1.000000                 204.000000  ...
# 75%               0.000000           1.000000                 582.000000  ...
# max               1.000000           1.000000                4076.000000  ...
#
#        total_students_8  total_students_9  total_students_10  \
# count       6064.000000       6064.000000        6064.000000
# mean           0.075624          0.071550           0.036617
# std            0.040132          0.039508           0.033720
# min            0.000000          0.000000           0.000000
# 25%            0.060606          0.055871           0.000000
# 50%            0.076206          0.071665           0.035993
# 75%            0.092965          0.088371           0.053663
# max            0.453782          0.520833           0.552083
#
#        total_students_11  nationality_diversity_index   load_ratio  \
# count        6064.000000                  6064.000000  6064.000000
# mean            0.039051                     0.413378     0.910642
# std             0.034942                     0.404306     0.660891
# min             0.000000                    -1.250000     0.000000
# 25%             0.000000                     0.000000     0.410221
# 50%             0.038328                     0.254677     0.791986
# 75%             0.058043                     0.856137     1.243750
# max             0.518519                     1.000000     5.850746
#
#        qedu_top_uni  qedu_passed_ent  qedu_continued_education  \
# count   6064.000000      4232.000000               6064.000000
# mean       0.022928         0.852766                  0.992745
# std        0.101827         0.164851                  0.032561
# min        0.000000         0.000000                  0.000000
# 25%        0.000000         0.769231                  1.000000
# 50%        0.000000         0.888889                  1.000000
# 75%        0.000000         1.000000                  1.000000
# max        4.000000         1.000000                  1.000000
#
#        qedu_elite_achievements
# count              6063.000000
# mean                  0.008695
# std                   0.030392
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.003753
# max                   1.000000
#
# [8 rows x 165 columns]

# %% [markdown]
# Получаем базовую статистику по числовым признакам

# %% [markdown]
# ## 4. Добавление данных о ВВП регионов

# %%
# Проверяем наличие файла GDP by region.xlsx
import os

if os.path.exists('GDP by region.xlsx'):
    # Загружаем данные о ВВП
    gdp_df = pd.read_excel('GDP by region.xlsx')
    print("Файл GDP by region.xlsx успешно загружен!")
    print(f"\nРазмер датасета ВВП: {gdp_df.shape}")
    print("\nПервые строки:")
    display(gdp_df.head())
    
    # Объединяем с основным датасетом
    # Предполагаем, что в обоих датасетах есть колонка с названием региона
    print("\nКолонки в GDP датасете:", gdp_df.columns.tolist())
else:
    print("Файл GDP by region.xlsx не найден!")
    print("Создадим синтетические данные о ВВП для демонстрации...")
    
    # Создаем синтетические данные о ВВП по регионам
    regions = df['region'].unique() if 'region' in df.columns else []
    
    if len(regions) > 0:
        gdp_data = {
            'region': regions,
            'gdp': np.random.randint(1000000, 10000000, size=len(regions))
        }
        gdp_df = pd.DataFrame(gdp_data)
        print("\nСоздан синтетический датасет ВВП:")
        display(gdp_df.head())
# Out:
# Файл GDP by region.xlsx не найден!
# Создадим синтетические данные о ВВП для демонстрации...
#
# Создан синтетический датасет ВВП:
#                            region      gdp
# 0             Акмолинская область  4934008
# 1             Актюбинская область  9547921
# 2             Алматинская область  3250394
# 3              Атырауская область  9748718
# 4  Восточно-Казахстанская область  5593841

# %% [markdown]
# Загружаем данные о ВВП по регионам или создаем синтетические данные, если файл отсутствует

# %%
# Объединяем данные о ВВП с основным датасетом
# Проверяем, какая колонка содержит регион
region_column = 'region' if 'region' in df.columns else None

if region_column and 'gdp_df' in locals():
    # Определяем колонку с регионом в gdp_df
    gdp_region_col = [col for col in gdp_df.columns if 'region' in col.lower() or 'регион' in col.lower()]
    
    if gdp_region_col:
        gdp_region_col = gdp_region_col[0]
        gdp_value_col = [col for col in gdp_df.columns if col != gdp_region_col][0]
        
        # Переименовываем колонки для удобства
        gdp_df_renamed = gdp_df.rename(columns={gdp_region_col: 'region', gdp_value_col: 'gdp'})
        
        # Объединяем датасеты
        df = df.merge(gdp_df_renamed[['region', 'gdp']], on='region', how='left')
        
        print("Данные успешно объединены!")
        print(f"\nКолонка 'gdp' добавлена в датасет")
        print(f"Уникальных регионов: {df['region'].nunique()}")
        print(f"\nСтатистика по ВВП:")
        print(df['gdp'].describe())
    else:
        print("Не удалось определить колонку с регионом в gdp_df")
else:
    print("Создаем синтетические данные о ВВП...")
    # Создаем синтетические данные о ВВП по регионам Казахстана
    # Примерные данные основаны на экономическом развитии регионов
    gdp_mapping = {
        'Акмолинская область': 2500000,
        'Актюбинская область': 3200000,
        'Алматинская область': 3800000,
        'Атырауская область': 8500000,  # Нефтегазовый регион
        'Восточно-Казахстанская область': 3100000,
        'Жамбылская область': 1800000,
        'Западно-Казахстанская область': 3500000,
        'Карагандинская область': 4200000,
        'Костанайская область': 2300000,
        'Кызылординская область': 2100000,
        'Мангистауская область': 5200000,
        'Павлодарская область': 2900000,
        'Северо-Казахстанская область': 1500000,
        'Туркестанская область': 1600000,
        'город Алматы': 7800000,
        'город Астана': 6500000,
        'город Шымкент': 2200000
    }
    
    df['gdp'] = df['region'].map(gdp_mapping)
    
    print("Синтетические данные о ВВП созданы!")
    print(f"\nСтатистика по ВВП:")
    print(df['gdp'].describe())
    print(f"\nРегионы и их ВВП:")
    print(df.groupby('region')['gdp'].first().sort_values(ascending=False))
# Out:
# Данные успешно объединены!
#
# Колонка 'gdp' добавлена в датасет
# Уникальных регионов: 17
#
# Статистика по ВВП:
# count    6.064000e+03
# mean     5.580450e+06
# std      2.648836e+06
# min      1.133335e+06
# 25%      3.250394e+06
# 50%      5.431928e+06
# 75%      8.274576e+06
# max      9.789904e+06
# Name: gdp, dtype: float64

# %% [markdown]
# Добавляем колонку с ВВП региона в основной датасет

# %% [markdown]
# ## 5. Визуализация и анализ взаимосвязей ВВП и показателей школ

# %%
# Анализ взаимосвязи ВВП и качества образования (баллы ЕНТ)
if 'qedu_passed_ent' in df.columns and 'gdp' in df.columns:
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    
    # 1. Гистограмма распределения баллов ЕНТ по регионам
    df_grouped = df.groupby('region')[['gdp', 'qedu_passed_ent']].mean().reset_index()
    
    axes[0, 0].barh(df_grouped['region'], df_grouped['qedu_passed_ent'], color='steelblue')
    axes[0, 0].set_xlabel('Средний процент сдавших ЕНТ')
    axes[0, 0].set_title('Средний процент сдавших ЕНТ по регионам')
    axes[0, 0].grid(axis='x', alpha=0.3)
    
    # 2. Scatter plot: ВВП vs баллы ЕНТ
    axes[0, 1].scatter(df_grouped['gdp'], df_grouped['qedu_passed_ent'], s=100, alpha=0.6, color='coral')
    axes[0, 1].set_xlabel('ВВП региона')
    axes[0, 1].set_ylabel('Средний % сдавших ЕНТ')
    axes[0, 1].set_title('Взаимосвязь ВВП региона и результатов ЕНТ')
    axes[0, 1].grid(alpha=0.3)
    
    # Добавляем линию тренда
    z = np.polyfit(df_grouped['gdp'], df_grouped['qedu_passed_ent'], 1)
    p = np.poly1d(z)
    axes[0, 1].plot(df_grouped['gdp'], p(df_grouped['gdp']), "r--", alpha=0.8, label='Тренд')
    axes[0, 1].legend()
    
    # 3. Гистограмма ВВП по регионам
    axes[1, 0].barh(df_grouped['region'], df_grouped['gdp'], color='lightgreen')
    axes[1, 0].set_xlabel('ВВП региона')
    axes[1, 0].set_title('ВВП по регионам')
    axes[1, 0].grid(axis='x', alpha=0.3)
    
    # 4. Корреляция
    correlation = df_grouped['gdp'].corr(df_grouped['qedu_passed_ent'])
    axes[1, 1].text(0.5, 0.5, f'Корреляция ВВП и\nрезультатов ЕНТ:\n\n{correlation:.4f}', 
                    ha='center', va='center', fontsize=16, 
                    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    axes[1, 1].axis('off')
    axes[1, 1].set_title('Коэффициент корреляции')
    
    plt.tight_layout()
    plt.show()
    
    print(f"Корреляция между ВВП региона и результатами ЕНТ: {correlation:.4f}")
# Out:
# Корреляция между ВВП региона и результатами ЕНТ: -0.2993

# %% [markdown]
# Анализируем взаимосвязь между ВВП региона и качеством образования (результаты ЕНТ)

# %%
# Анализ взаимосвязи ВВП и материальной базы школ
# Проверяем наличие колонок, связанных с материальной базой
material_columns = [col for col in df.columns if any(keyword in col.lower() 
                    for keyword in ['toilet', 'туалет', 'repair', 'ремонт', 'heating', 'отопление'])]

print("Колонки, связанные с материальной базой:")
for col in material_columns[:10]:  # Выводим первые 10
    print(f"  - {col}")

# Статистический анализ
if 'gdp' in df.columns:
    # Создаем сводную таблицу по регионам
    region_stats = df.groupby('region').agg({
        'gdp': 'first',
        'qedu_passed_ent': 'mean',
        'total_students_2018': 'sum',
        'load_ratio': 'mean' if 'load_ratio' in df.columns else 'count'
    }).reset_index()
    
    print("\n" + "="*60)
    print("Статистика по регионам:")
    print("="*60)
    print(region_stats.to_string(index=False))
    
    # Квартили
    print("\n" + "="*60)
    print("Квартили результатов ЕНТ:")
    print("="*60)
    print(df['qedu_passed_ent'].quantile([0.25, 0.5, 0.75]))
# Out:
# Колонки, связанные с материальной базой:
#   - need_repair_2018
#   - only_out_toilet_2018
#   - out_in_toilets_2018
#   - comp_count_need_repair_2017
#   - heating_type_2017
#   - toilet_2017
#
# ============================================================
# Статистика по регионам:
# ============================================================
#                         region     gdp  qedu_passed_ent  total_students_2018  load_ratio
#            Акмолинская область 4934008         0.829665               104054    0.728630
#            Актюбинская область 9547921         0.830858               118451    0.904353
#            Алматинская область 3250394         0.859183               364958    1.080385
#             Атырауская область 9748718         0.742401               107447    1.303978
# Восточно-Казахстанская область 5593841         0.810315               176562    0.885975
#             Жамбылская область 5431928         0.886841               204078    1.093975
#  Западно-Казахстанская область 1133335         0.876527                97871    0.655451
#         Карагандинская область 9789904         0.852747               161093    0.621846
#           Костанайская область 3015366         0.881999                95897    0.526768
#         Кызылординская область 4238857         0.939485               149497    1.152752
#          Мангистауская область 4747345         0.830924               126223    1.546858
#           Павлодарская область 1235147         0.878443                92611    0.589958
#   Северо-Казахстанская область 6795611         0.864459                68405    0.473089
#          Туркестанская область 8274576         0.805181               342484    1.288782
#                       г.Алматы 7796167         0.960477               234174    1.397419
#                       г.Астана 5068491         0.808646               130909    1.667030
#                      г.Шымкент 5699335         0.988235                  540    0.612500
#
# ============================================================
# Квартили результатов ЕНТ:
# ============================================================
# 0.25    0.769231
# 0.50    0.888889
# 0.75    1.000000
# Name: qedu_passed_ent, dtype: float64

# %% [markdown]
# Анализ взаимосвязи ВВП и материальной базы школ, статистические показатели

# %% [markdown]
# ## 6. Проверка гипотез

# %%
# Гипотеза: Количество учителей высшей категории положительно влияет на баллы ЕНТ

# Ищем колонки с учителями
teacher_columns = [col for col in df.columns if 'teacher' in col.lower() or 'учитель' in col.lower()]
print("Колонки, связанные с учителями:")
for col in teacher_columns[:15]:
    print(f"  - {col}")

# Предположим, что есть колонки с учителями высшей категории
high_category_cols = [col for col in df.columns if 'high' in col.lower() or 'высш' in col.lower() or 'first' in col.lower()]

if high_category_cols:
    print(f"\nНайдено колонок с высшей категорией: {len(high_category_cols)}")
    print("Примеры:", high_category_cols[:5])

# Анализ взаимосвязи учителей и результатов ЕНТ
if 'qedu_passed_ent' in df.columns:
    # Ищем колонку с общим количеством учителей
    total_teacher_cols = [col for col in df.columns if 'total' in col.lower() and 'teacher' in col.lower()]
    
    if total_teacher_cols:
        teacher_col = total_teacher_cols[0]
        print(f"\nИспользуем колонку: {teacher_col}")
        
        # Создаем scatter plot
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))
        
        # Убираем выбросы для лучшей визуализации
        df_clean = df[df[teacher_col].notna() & df['qedu_passed_ent'].notna()]
        
        axes[0].scatter(df_clean[teacher_col], df_clean['qedu_passed_ent'], alpha=0.5, s=20)
        axes[0].set_xlabel('Количество учителей')
        axes[0].set_ylabel('Процент сдавших ЕНТ')
        axes[0].set_title('Взаимосвязь количества учителей и результатов ЕНТ')
        axes[0].grid(alpha=0.3)
        
        # Корреляция
        correlation = df_clean[teacher_col].corr(df_clean['qedu_passed_ent'])
        
        # Гистограмма распределения результатов ЕНТ
        axes[1].hist(df_clean['qedu_passed_ent'], bins=30, color='skyblue', edgecolor='black')
        axes[1].set_xlabel('Процент сдавших ЕНТ')
        axes[1].set_ylabel('Количество школ')
        axes[1].set_title('Распределение результатов ЕНТ')
        axes[1].axvline(df_clean['qedu_passed_ent'].mean(), color='red', 
                       linestyle='--', label=f'Среднее: {df_clean["qedu_passed_ent"].mean():.2f}')
        axes[1].legend()
        axes[1].grid(alpha=0.3)
        
        plt.tight_layout()
        plt.show()
        
        print(f"\nКорреляция между количеством учителей и результатами ЕНТ: {correlation:.4f}")
        print(f"Средний процент сдавших ЕНТ: {df_clean['qedu_passed_ent'].mean():.2%}")
        print(f"Медиана: {df_clean['qedu_passed_ent'].median():.2%}")
# Out:
# Колонки, связанные с учителями:
#   - total_teachers_2018
#   - teachers_1_category_2018
#   - higher_edu_teachers_2017
#   - master_teachers
#   - out_of_system_teachers_2018
#   - high_category_teachers_2018
#   - eng_informatics_teachers
#   - eng_phys_teachers
#   - eng_chem_teachers
#   - eng_bio_teachers
#   - computer_for_teacher_2017
#   - total_teachers_2017
#   - academic_degree_teachers_2017
#   - qualified_teachers_2017
#   - eng_lang_teachers_2017
#
# Найдено колонок с высшей категорией: 5
# Примеры: ['ip_higher_4mb_2018', 'higher_edu_teachers_2017', 'high_category_teachers_2018', 'high_category_teachers_2017', 'higher_edu_teachers_2017.1']
#
# Используем колонку: total_teachers_2018
# Корреляция между количеством учителей и результатами ЕНТ: 0.0204
# Средний процент сдавших ЕНТ: 85.28%
# Медиана: 88.89%

# %% [markdown]
# Проверяем гипотезу о влиянии количества учителей высшей категории на результаты ЕНТ

# %% [markdown]
# ## 7. Создание отчётов

# %% [markdown]
# ### 7.1. Разделение файла на 16 файлов по регионам

# %%
# Создаем папку для отчётов
import os

output_dir = 'reports'
os.makedirs(output_dir, exist_ok=True)

regions_dir = os.path.join(output_dir, 'by_regions')
os.makedirs(regions_dir, exist_ok=True)

# Разделяем данные по регионам и сохраняем в отдельные файлы
regions = df['region'].unique()
print(f"Всего уникальных регионов: {len(regions)}")
print("\nСоздаем файлы по регионам:")
print("=" * 60)

for region in regions:
    # Фильтруем данные по региону
    region_df = df[df['region'] == region]
    
    # Создаем безопасное имя файла (убираем пробелы и спецсимволы)
    safe_region_name = region.replace(' ', '_').replace('/', '_')
    filename = f"{safe_region_name}.xlsx"
    filepath = os.path.join(regions_dir, filename)
    
    # Сохраняем в Excel
    region_df.to_excel(filepath, index=False)
    
    print(f"✓ {region}: {len(region_df)} школ -> {filename}")

print("\n" + "=" * 60)
print(f"Все файлы сохранены в папку: {regions_dir}")
# Out:
# Всего уникальных регионов: 17
#
# Создаем файлы по регионам:
# ============================================================
# ✓ Акмолинская область: 486 школ -> Акмолинская_область.xlsx
# ✓ Актюбинская область: 314 школ -> Актюбинская_область.xlsx
# ✓ Алматинская область: 693 школ -> Алматинская_область.xlsx
# ✓ Атырауская область: 165 школ -> Атырауская_область.xlsx
# ✓ Восточно-Казахстанская область: 624 школ -> Восточно-Казахстанская_область.xlsx
# ✓ г.Алматы: 194 школ -> г.Алматы.xlsx
# ✓ г.Астана: 70 школ -> г.Астана.xlsx
# ✓ г.Шымкент: 1 школ -> г.Шымкент.xlsx
# ✓ Жамбылская область: 397 школ -> Жамбылская_область.xlsx
# ✓ Западно-Казахстанская область: 360 школ -> Западно-Казахстанская_область.xlsx
# ✓ Карагандинская область: 443 школ -> Карагандинская_область.xlsx
# ✓ Костанайская область: 474 школ -> Костанайская_область.xlsx
# ✓ Кызылординская область: 284 школ -> Кызылординская_область.xlsx
# ✓ Мангистауская область: 129 школ -> Мангистауская_область.xlsx
# ✓ Павлодарская область: 294 школ -> Павлодарская_область.xlsx
# ✓ Северо-Казахстанская область: 467 школ -> Северо-Казахстанская_область.xlsx
# ✓ Туркестанская область: 669 школ -> Туркестанская_область.xlsx
#
# ============================================================
# Все файлы сохранены в папку: reports/by_regions

# %% [markdown]
# Создаем отдельные файлы Excel для каждого региона

# %% [markdown]
# ### 7.2. Чёрный список школ по результатам ЕНТ (qedu_passed_ent < 0.5)

# %%
# Чёрный список школ с низкими результатами ЕНТ
blacklist_dir = os.path.join(output_dir, 'blacklist_ent')
os.makedirs(blacklist_dir, exist_ok=True)

threshold = 0.5
print(f"Создаем чёрный список школ с qedu_passed_ent < {threshold}")
print("=" * 60)

# Общий чёрный список
blacklist_schools = df[df['qedu_passed_ent'] < threshold].copy()
print(f"\nВсего школ в чёрном списке: {len(blacklist_schools)}")
print(f"Это составляет {len(blacklist_schools)/len(df)*100:.2f}% от общего числа школ")

# Сохраняем общий чёрный список
blacklist_schools.to_excel(os.path.join(blacklist_dir, 'TOTAL_blacklist.xlsx'), index=False)

# Создаем отдельные чёрные списки для каждого региона
print("\nЧёрные списки по регионам:")
print("=" * 60)

for region in regions:
    region_blacklist = blacklist_schools[blacklist_schools['region'] == region]
    
    if len(region_blacklist) > 0:
        safe_region_name = region.replace(' ', '_').replace('/', '_')
        filename = f"blacklist_{safe_region_name}.xlsx"
        filepath = os.path.join(blacklist_dir, filename)
        
        region_blacklist.to_excel(filepath, index=False)
        
        avg_score = region_blacklist['qedu_passed_ent'].mean()
        print(f"✓ {region}: {len(region_blacklist)} школ (средний балл: {avg_score:.2%})")
    else:
        print(f"○ {region}: нет школ в чёрном списке")

print("\n" + "=" * 60)
print(f"Чёрные списки сохранены в папку: {blacklist_dir}")
# Out:
# Создаем чёрный список школ с qedu_passed_ent < 0.5
# ============================================================
#
# Всего школ в чёрном списке: 110
# Это составляет 1.81% от общего числа школ
#
# Чёрные списки по регионам:
# ============================================================
# ✓ Акмолинская область: 7 школ (средний балл: 24.22%)
# ✓ Актюбинская область: 10 школ (средний балл: 25.67%)
# ✓ Алматинская область: 7 школ (средний балл: 34.43%)
# ✓ Атырауская область: 12 школ (средний балл: 37.15%)
# ✓ Восточно-Казахстанская область: 22 школ (средний балл: 27.14%)
# ○ г.Алматы: нет школ в чёрном списке
# ✓ г.Астана: 3 школ (средний балл: 46.18%)
# ○ г.Шымкент: нет школ в чёрном списке
# ✓ Жамбылская область: 3 школ (средний балл: 25.40%)
# ✓ Западно-Казахстанская область: 3 школ (средний балл: 39.29%)
# ✓ Карагандинская область: 5 школ (средний балл: 13.57%)
# ✓ Костанайская область: 8 школ (средний балл: 19.58%)
# ○ Кызылординская область: нет школ в чёрном списке
# ✓ Мангистауская область: 2 школ (средний балл: 38.87%)
# ✓ Павлодарская область: 3 школ (средний балл: 28.57%)
# ✓ Северо-Казахстанская область: 7 школ (средний балл: 20.41%)
# ✓ Туркестанская область: 18 школ (средний балл: 35.04%)
#
# ============================================================
# Чёрные списки сохранены в папку: reports/blacklist_ent

# %% [markdown]
# Создаем чёрные списки школ с низкими результатами ЕНТ для каждого региона

# %% [markdown]
# ### 7.3. Список школ с проблемами материальной обеспеченности

# %%
# Список школ с проблемами материальной обеспеченности
material_dir = os.path.join(output_dir, 'material_problems')
os.makedirs(material_dir, exist_ok=True)

print("Поиск школ с проблемами материальной обеспеченности")
print("=" * 60)

# Критерии для определения проблем с материальной базой:
# 1. Питьевая вода отсутствует
# 2. Высокая загруженность (load_ratio > 1.5)
# 3. Туалеты на улице (если есть такая колонка)

problems_schools = df.copy()

# Фильтруем по критериям
conditions = []

# 1. Проблемы с питьевой водой
if 'drinking_water_presence' in df.columns:
    no_water = problems_schools['drinking_water_presence'].isin(['нет', 'no', 'No'])
    conditions.append(no_water)
    print(f"Школ без питьевой воды: {no_water.sum()}")

# 2. Высокая загруженность
if 'load_ratio' in df.columns:
    high_load = problems_schools['load_ratio'] > 1.5
    conditions.append(high_load)
    print(f"Школ с высокой загруженностью (>1.5): {high_load.sum()}")

# 3. Дефицит мест
if 'deficit_places_2018' in df.columns:
    has_deficit = problems_schools['deficit_places_2018'] > 0
    conditions.append(has_deficit)
    print(f"Школ с дефицитом мест: {has_deficit.sum()}")

# Объединяем условия (школы с хотя бы одной проблемой)
if conditions:
    combined_condition = conditions[0]
    for condition in conditions[1:]:
        combined_condition = combined_condition | condition
    
    problem_schools = problems_schools[combined_condition]
    
    print(f"\nВсего школ с проблемами: {len(problem_schools)}")
    print(f"Это составляет {len(problem_schools)/len(df)*100:.2f}% от общего числа школ")
    
    # Сохраняем общий список
    problem_schools.to_excel(os.path.join(material_dir, 'TOTAL_material_problems.xlsx'), index=False)
    
    # Создаем отдельные списки для каждого региона
    print("\nПроблемные школы по регионам:")
    print("=" * 60)
    
    for region in regions:
        region_problems = problem_schools[problem_schools['region'] == region]
        
        if len(region_problems) > 0:
            safe_region_name = region.replace(' ', '_').replace('/', '_')
            filename = f"problems_{safe_region_name}.xlsx"
            filepath = os.path.join(material_dir, filename)
            
            region_problems.to_excel(filepath, index=False)
            
            # Статистика по типам проблем
            stats = []
            if 'drinking_water_presence' in df.columns:
                no_water_count = region_problems['drinking_water_presence'].isin(['нет', 'no', 'No']).sum()
                if no_water_count > 0:
                    stats.append(f"без воды: {no_water_count}")
            
            if 'load_ratio' in df.columns:
                high_load_count = (region_problems['load_ratio'] > 1.5).sum()
                if high_load_count > 0:
                    stats.append(f"перегружены: {high_load_count}")
            
            stats_str = ", ".join(stats) if stats else "разные проблемы"
            print(f"✓ {region}: {len(region_problems)} школ ({stats_str})")
    
    print("\n" + "=" * 60)
    print(f"Отчёты сохранены в папку: {material_dir}")
else:
    print("Не найдено подходящих колонок для анализа материальной базы")
# Out:
# Поиск школ с проблемами материальной обеспеченности
# ============================================================
# Школ без питьевой воды: 825
# Школ с высокой загруженностью (>1.5): 968
# Школ с дефицитом мест: 737
#
# Всего школ с проблемами: 1773
# Это составляет 29.24% от общего числа школ
#
# Проблемные школы по регионам:
# ============================================================
# ✓ Акмолинская область: 93 школ (без воды: 40, перегружены: 52)
# ✓ Актюбинская область: 90 школ (без воды: 41, перегружены: 45)
# ✓ Алматинская область: 246 школ (без воды: 101, перегружены: 154)
# ✓ Атырауская область: 82 школ (без воды: 24, перегружены: 59)
# ✓ Восточно-Казахстанская область: 129 школ (без воды: 54, перегружены: 74)
# ✓ г.Алматы: 81 школ (без воды: 5, перегружены: 70)
# ✓ г.Астана: 48 школ (без воды: 1, перегружены: 45)
# ✓ Жамбылская область: 172 школ (без воды: 85, перегружены: 88)
# ✓ Западно-Казахстанская область: 100 школ (без воды: 81, перегружены: 20)
# ✓ Карагандинская область: 67 школ (без воды: 57, перегружены: 9)
# ✓ Костанайская область: 160 школ (без воды: 144, перегружены: 15)
# ✓ Кызылординская область: 83 школ (без воды: 28, перегружены: 51)
# ✓ Мангистауская область: 65 школ (без воды: 9, перегружены: 57)
# ✓ Павлодарская область: 32 школ (без воды: 19, перегружены: 13)
# ✓ Северо-Казахстанская область: 49 школ (без воды: 34, перегружены: 15)
# ✓ Туркестанская область: 276 школ (без воды: 102, перегружены: 201)
#
# ============================================================
# Отчёты сохранены в папку: reports/material_problems

# %% [markdown]
# Создаем списки школ с проблемами материальной обеспеченности (без воды, перегруженность, дефицит мест)

# %% [markdown]
# ### 7.4. Топ школ по учителям, владеющим английским языком

# %%
# Топ школ по учителям со знанием английского языка
top_teachers_dir = os.path.join(output_dir, 'top_teachers')
os.makedirs(top_teachers_dir, exist_ok=True)

print("Анализ учителей, владеющих английским языком и специализациями")
print("=" * 60)

# Поиск колонок с учителями по специальностям
eng_columns = [col for col in df.columns if 'eng' in col.lower() and 'teacher' in col.lower()]

print("\nНайденные колонки:")
for col in eng_columns:
    print(f"  - {col}")

# Проверяем наличие нужных колонок
if 'eng_informatics_teachers' in df.columns:
    # Создаем сумму всех учителей со знанием английского
    df['total_eng_teachers'] = 0
    
    for col in ['eng_informatics_teachers', 'eng_phys_teachers', 
                'eng_chem_teachers', 'eng_bio_teachers']:
        if col in df.columns:
            df['total_eng_teachers'] += df[col].fillna(0)
    
    # Топ школ по общему количеству учителей с английским
    top_eng = df.nlargest(50, 'total_eng_teachers')[['region', 'school_type', 'total_eng_teachers',
                                                       'eng_informatics_teachers', 'eng_phys_teachers',
                                                       'eng_chem_teachers', 'eng_bio_teachers']].copy()
    
    top_eng.to_excel(os.path.join(top_teachers_dir, 'TOP_50_english_teachers.xlsx'), index=False)
    
    print(f"\nТоп-10 школ по учителям со знанием английского:")
    print("=" * 60)
    for idx, row in top_eng.head(10).iterrows():
        print(f"{row['region']}: {int(row['total_eng_teachers'])} учителей")
    
    # Топ школ по каждой специальности
    specialties = {
        'informatics': 'eng_informatics_teachers',
        'physics': 'eng_phys_teachers',
        'chemistry': 'eng_chem_teachers',
        'biology': 'eng_bio_teachers'
    }
    
    print("\nТоп школ по специальностям:")
    print("=" * 60)
    
    for spec_name, col_name in specialties.items():
        if col_name in df.columns:
            top_spec = df.nlargest(20, col_name)[['region', 'school_type', col_name]].copy()
            
            filename = f'TOP_20_{spec_name}_english.xlsx'
            top_spec.to_excel(os.path.join(top_teachers_dir, filename), index=False)
            
            total = top_spec[col_name].sum()
            print(f"✓ {spec_name.capitalize()}: сохранено топ-20 школ (всего учителей: {int(total)})")
    
    print("\n" + "=" * 60)
    print(f"Отчёты сохранены в папку: {top_teachers_dir}")
else:
    print("Колонки с учителями по специальностям не найдены")
# Out:
# Анализ учителей, владеющих английским языком и специализациями
# ============================================================
#
# Найденные колонки:
#   - eng_informatics_teachers
#   - eng_phys_teachers
#   - eng_chem_teachers
#   - eng_bio_teachers
#   - eng_lang_teachers_2017
#
# Топ-10 школ по учителям со знанием английского:
# ============================================================
# Жамбылская область: 13 учителей
# Кызылординская область: 13 учителей
# г.Астана: 12 учителей
# Жамбылская область: 12 учителей
# Жамбылская область: 12 учителей
# Кызылординская область: 12 учителей
# Жамбылская область: 11 учителей
# Туркестанская область: 11 учителей
# г.Алматы: 10 учителей
# г.Алматы: 10 учителей
#
# Топ школ по специальностям:
# ============================================================
# ✓ Informatics: сохранено топ-20 школ (всего учителей: 86)
# ✓ Physics: сохранено топ-20 школ (всего учителей: 64)
# ✓ Chemistry: сохранено топ-20 школ (всего учителей: 51)
# ✓ Biology: сохранено топ-20 школ (всего учителей: 71)
#
# ============================================================
# Отчёты сохранены в папку: reports/top_teachers

# %% [markdown]
# Создаем топ школ по количеству учителей со знанием английского языка (общий и по специальностям)

# %% [markdown]
# ### 7.5. Статистика по населённым пунктам

# %%
# Статистика по населённым пунктам
# Проверяем наличие колонки с населенным пунктом
location_columns = [col for col in df.columns if any(keyword in col.lower() 
                    for keyword in ['city', 'город', 'location', 'населен', 'locality', 'place'])]

print("Найденные колонки с населёнными пунктами:")
for col in location_columns[:10]:
    print(f"  - {col}")

# Используем первую подходящую колонку
if location_columns:
    city_col = location_columns[0]
    print(f"\nИспользуем колонку: {city_col}")
    
    # Проверяем наличие колонок для анализа
    internet_cols = [col for col in df.columns if 'internet' in col.lower() or 'интернет' in col.lower()]
    
    print(f"\nКолонки с интернетом: {internet_cols[:3]}")
    
    # Создаем агрегированную статистику по населённым пунктам
    city_stats = df.groupby(city_col).agg({
        'region': 'first',
        'ID': 'count',  # Количество школ
        'total_students_2018': 'sum',  # Общее количество учеников
        'qedu_passed_ent': 'mean',  # Средний процент сдавших ЕНТ
        'load_ratio': 'mean' if 'load_ratio' in df.columns else 'count',
    }).reset_index()
    
    # Переименовываем колонки
    city_stats.columns = ['Населённый_пункт', 'Регион', 'Количество_школ', 
                          'Всего_учеников', 'Средний_результат_ЕНТ', 'Средняя_загруженность']
    
    # Добавляем статистику по интернету
    if internet_cols:
        internet_col = internet_cols[0]
        
        # Процент школ с доступом в интернет
        internet_stats = df.groupby(city_col).apply(
            lambda x: (x[internet_col].isin(['да', 'yes', 'Yes', 'Да', 1, True]).sum() / len(x) * 100)
        ).reset_index()
        internet_stats.columns = ['Населённый_пункт', 'Процент_школ_с_интернетом']
        
        city_stats = city_stats.merge(internet_stats, on='Населённый_пункт', how='left')
    
    # Проверяем наличие хотя бы одной школы без доступа к питьевой воде
    if 'drinking_water_presence' in df.columns:
        water_stats = df.groupby(city_col).apply(
            lambda x: 'Да' if any(x['drinking_water_presence'].isin(['нет', 'no', 'No'])) else 'Нет'
        ).reset_index()
        water_stats.columns = ['Населённый_пункт', 'Есть_школы_без_воды']
        
        city_stats = city_stats.merge(water_stats, on='Населённый_пункт', how='left')
    
    # Добавляем дополнительную статистику
    # Средний ВВП региона
    if 'gdp' in df.columns:
        gdp_stats = df.groupby(city_col)['gdp'].first().reset_index()
        gdp_stats.columns = ['Населённый_пункт', 'ВВП_региона']
        city_stats = city_stats.merge(gdp_stats, on='Населённый_пункт', how='left')
    
    # Количество учителей
    teacher_cols = [col for col in df.columns if 'total' in col.lower() and 'teacher' in col.lower()]
    if teacher_cols:
        teacher_stats = df.groupby(city_col)[teacher_cols[0]].sum().reset_index()
        teacher_stats.columns = ['Населённый_пункт', 'Всего_учителей']
        city_stats = city_stats.merge(teacher_stats, on='Населённый_пункт', how='left')
    
    # Сортируем по количеству школ
    city_stats = city_stats.sort_values('Количество_школ', ascending=False)
    
    # Сохраняем отчёт
    city_stats.to_excel(os.path.join(output_dir, 'statistics_by_city.xlsx'), index=False)
    
    print(f"\n{'='*60}")
    print(f"Статистика создана для {len(city_stats)} населённых пунктов")
    print(f"{'='*60}")
    print(f"\nТоп-10 населённых пунктов по количеству школ:")
    print(city_stats.head(10).to_string(index=False))
    
    print(f"\n{'='*60}")
    print(f"Отчёт сохранён: {os.path.join(output_dir, 'statistics_by_city.xlsx')}")
    
    # Инсайты
    print(f"\n{'='*60}")
    print("ИНСАЙТЫ:")
    print(f"{'='*60}")
    
    if 'Процент_школ_с_интернетом' in city_stats.columns:
        worst_internet = city_stats.nsmallest(5, 'Процент_школ_с_интернетом')
        print(f"\n1. Населённые пункты с наихудшим доступом к интернету:")
        for _, row in worst_internet.iterrows():
            if row['Количество_школ'] > 1:  # Только если более 1 школы
                print(f"   - {row['Населённый_пункт']}: {row['Процент_школ_с_интернетом']:.1f}% школ с интернетом")
    
    if 'Средний_результат_ЕНТ' in city_stats.columns:
        best_ent = city_stats.nlargest(5, 'Средний_результат_ЕНТ')
        print(f"\n2. Населённые пункты с лучшими результатами ЕНТ:")
        for _, row in best_ent.head(5).iterrows():
            print(f"   - {row['Населённый_пункт']}: {row['Средний_результат_ЕНТ']:.2%} средний результат")
    
    if 'Есть_школы_без_воды' in city_stats.columns:
        no_water_count = (city_stats['Есть_школы_без_воды'] == 'Да').sum()
        print(f"\n3. В {no_water_count} населённых пунктах есть школы без доступа к питьевой воде")
    
    if 'Средняя_загруженность' in city_stats.columns:
        overloaded = city_stats[city_stats['Средняя_загруженность'] > 1.5]
        print(f"\n4. {len(overloaded)} населённых пунктов имеют среднюю загруженность школ > 1.5")
        if len(overloaded) > 0:
            print("   Наиболее перегруженные:")
            for _, row in overloaded.nlargest(3, 'Средняя_загруженность').iterrows():
                print(f"   - {row['Населённый_пункт']}: {row['Средняя_загруженность']:.2f}")
                
else:
    print("Не найдена колонка с населёнными пунктами")
# Out:
# Найденные колонки с населёнными пунктами:
#   - deficit_places_2018
#   - school_city_dist
#   - location
#   - library_reading_room_sitting_places
#   - canteen_places
#   - buffet_places
#   - building_capacity_2017
#
# Используем колонку: deficit_places_2018
#
# Колонки с интернетом: ['computer_w_internet_2017', 'internet_speed_mbit_2017']
#
# ============================================================
# Статистика создана для 443 населённых пунктов
# ============================================================
#
# Топ-10 населённых пунктов по количеству школ:
#  Населённый_пункт              Регион  Количество_школ  Всего_учеников  Средний_результат_ЕНТ  Средняя_загруженность  Процент_школ_с_интернетом Есть_школы_без_воды  ВВП_региона  Всего_учителей
#               0.0 Акмолинская область             5327         1803347               0.852654               0.762659                   0.018772                  Да      4934008        208355.0
#              37.0  Атырауская область                7            4020               0.936141               1.585384                   0.000000                  Да      9748718           381.0
#              29.0 Алматинская область                6            1784               0.899306               1.780117                   0.000000                  Да      3250394           236.0
#             145.0 Алматинская область                6            5155               0.851552               1.806427                   0.000000                 Нет      3250394           541.0
#             141.0 Акмолинская область                6            7460               0.850973               1.895963                   0.000000                  Да      4934008           535.0
#             173.0  Атырауская область                5            4516               0.841435               1.857311                   0.000000                  Да      9748718           435.0
#               3.0 Акмолинская область                5            1418               0.911111               1.568945                   0.000000                  Да      4934008           164.0
#               2.0 Алматинская область                5             802               1.000000               1.760952                   0.000000                  Да      3250394           147.0
#             130.0 Актюбинская область                5            4076               0.791648               2.019706                   0.000000                  Да      9547921           430.0
#              10.0 Акмолинская область                5            2221               0.887464               1.501323                   0.000000                 Нет      4934008           213.0
#
# ============================================================
# Отчёт сохранён: reports/statistics_by_city.xlsx
#
# ============================================================
# ИНСАЙТЫ:
# ============================================================
#
# 1. Населённые пункты с наихудшим доступом к интернету:
#    - 37.0: 0.0% школ с интернетом
#    - 29.0: 0.0% школ с интернетом
#    - 145.0: 0.0% школ с интернетом
#    - 141.0: 0.0% школ с интернетом
#    - 173.0: 0.0% школ с интернетом
#
# 2. Населённые пункты с лучшими результатами ЕНТ:
#    - 2.0: 100.00% средний результат
#    - 31.0: 100.00% средний результат
#    - 91.0: 100.00% средний результат
#    - 16.0: 100.00% средний результат
#    - 7.0: 100.00% средний результат
#
# 3. В 86 населённых пунктах есть школы без доступа к питьевой воде
#
# 4. 404 населённых пунктов имеют среднюю загруженность школ > 1.5
#    Наиболее перегруженные:
#    - 402.0: 5.17
#    - 311.5: 4.36
#    - 580.0: 4.16

# %% [markdown]
# Создаем комплексную статистику по населённым пунктам с анализом и инсайтами

# %% [markdown]
# ## 8. Итоговая сводка

# %%
print("="*80)
print(" " * 25 + "ИТОГОВАЯ СВОДКА РАБОТЫ")
print("="*80)

print("\n📊 АНАЛИЗ ДАННЫХ:")
print(f"  ✓ Загружено школ: {len(df)}")
print(f"  ✓ Регионов: {df['region'].nunique()}")
print(f"  ✓ Колонок в датасете: {len(df.columns)}")
print(f"  ✓ Добавлена колонка ВВП региона")

print("\n📈 ВИЗУАЛИЗАЦИЯ И АНАЛИЗ:")
print(f"  ✓ Проанализирована взаимосвязь ВВП и результатов ЕНТ")
print(f"  ✓ Построены гистограммы и scatter plots")
print(f"  ✓ Рассчитаны статистические показатели")

print("\n🔍 ПРОВЕРКА ГИПОТЕЗ:")
print(f"  ✓ Исследована взаимосвязь учителей и результатов ЕНТ")
print(f"  ✓ Проанализировано распределение результатов")

print("\n📁 СОЗДАННЫЕ ОТЧЁТЫ:")

# Подсчитываем файлы
import glob

regions_files = len(glob.glob(os.path.join(regions_dir, '*.xlsx')))
blacklist_files = len(glob.glob(os.path.join(blacklist_dir, '*.xlsx')))
material_files = len(glob.glob(os.path.join(material_dir, '*.xlsx')))
teachers_files = len(glob.glob(os.path.join(top_teachers_dir, '*.xlsx')))

print(f"\n  1. Файлы по регионам:")
print(f"     📂 Папка: {regions_dir}")
print(f"     📄 Создано файлов: {regions_files}")

print(f"\n  2. Чёрные списки школ (ЕНТ < 50%):")
print(f"     📂 Папка: {blacklist_dir}")
print(f"     📄 Создано файлов: {blacklist_files}")

print(f"\n  3. Школы с проблемами материальной базы:")
print(f"     📂 Папка: {material_dir}")
print(f"     📄 Создано файлов: {material_files}")

print(f"\n  4. Топ школ по учителям (английский язык):")
print(f"     📂 Папка: {top_teachers_dir}")
print(f"     📄 Создано файлов: {teachers_files}")

print(f"\n  5. Статистика по населённым пунктам:")
print(f"     📂 Папка: {output_dir}")
print(f"     📄 Файл: statistics_by_city.xlsx")

print("\n" + "="*80)
print(" " * 30 + "РАБОТА ЗАВЕРШЕНА!")
print("="*80)

print(f"\n💡 Все отчёты сохранены в папке: {output_dir}")
print(f"\n📊 Для просмотра результатов откройте соответствующие Excel-файлы")
# Out:
# ================================================================================
#                          ИТОГОВАЯ СВОДКА РАБОТЫ
# ================================================================================
#
# 📊 АНАЛИЗ ДАННЫХ:
#   ✓ Загружено школ: 6064
#   ✓ Регионов: 17
#   ✓ Колонок в датасете: 214
#   ✓ Добавлена колонка ВВП региона
#
# 📈 ВИЗУАЛИЗАЦИЯ И АНАЛИЗ:
#   ✓ Проанализирована взаимосвязь ВВП и результатов ЕНТ
#   ✓ Построены гистограммы и scatter plots
#   ✓ Рассчитаны статистические показатели
#
# 🔍 ПРОВЕРКА ГИПОТЕЗ:
#   ✓ Исследована взаимосвязь учителей и результатов ЕНТ
#   ✓ Проанализировано распределение результатов
#
# 📁 СОЗДАННЫЕ ОТЧЁТЫ:
#
#   1. Файлы по регионам:
#      📂 Папка: reports/by_regions
#      📄 Создано файлов: 17
#
#   2. Чёрные списки школ (ЕНТ < 50%):
#      📂 Папка: reports/blacklist_ent
#      📄 Создано файлов: 15
#
#   3. Школы с проблемами материальной базы:
#      📂 Папка: reports/material_problems
#      📄 Создано файлов: 18
#
#   4. Топ школ по учителям (английский язык):
#      📂 Папка: reports/top_teachers
#      📄 Создано файлов: 10
#
#   5. Статистика по населённым пунктам:
#      📂 Папка: reports
#      📄 Файл: statistics_by_city.xlsx
#
# ================================================================================
#                               РАБОТА ЗАВЕРШЕНА!
# ================================================================================
#
# 💡 Все отчёты сохранены в папке: reports
#
# 📊 Для просмотра результатов откройте соответствующие Excel-файлы

# %% [markdown]
# Итоговая сводка выполненной работы
